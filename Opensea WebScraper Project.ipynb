# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'Top NFTs _ OpenSea.html'
with open(url, encoding='utf-8') as fp:
	soup = BeautifulSoup(fp, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!-- saved from url=(0051)https://opensea.io/rankings?sortBy=seven_day_volume -->
# ...

# %% [markdown]
# Column Header Name

# %%
# <div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-4a4bbf51-0 egFVWu bNkKFC hPOmqI sc-163e4111-1 ia-Dfdl"><div class="sc-c0dd234a-0 sc-4a4bbf51-1 bpSPqV iwDeCi"><div class="flex justify-between sticky z-[1] h-full w-full items-center overflow-hidden border-none" style="top: 72px;"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-163e4111-0 dvzgPY hFSujt"><div class="sc-c0dd234a-0 copoim"><span class="text-sm leading-sm text-secondary" data-id="TextBody">#</span></div><span class="text-sm leading-sm sc-11af4f97-2 hGwLac" data-id="TextBody">Collection</span></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-163e4111-0 cyRNqz hFSujt"><button class="inline-flex items-center border-0 bg-inherit font-[inherit] text-[100%] sc-dd7510c8-0 bePMuJ" type="button" data-id="UnstyledButton"><span class="text-sm leading-sm sc-11af4f97-4 hhVWHy" data-id="TextBody">Volume</span><div class="sc-c0dd234a-0 sc-630fc9ab-0 gUjWRO bNkKFC"><i class="material-symbols-outlined cursor-pointer" translate="no" data-id="Icon" style="font-size: 20px; font-variation-settings: &quot;FILL&quot; 0, &quot;wght&quot; 400, &quot;GRAD&quot; 0, &quot;opsz&quot; 14;">expand_more</i></div></button></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-163e4111-0 cyRNqz hFSujt"><button class="inline-flex items-center border-0 bg-inherit font-[inherit] text-[100%] sc-dd7510c8-0 cFKxd" type="button" data-id="UnstyledButton"><span class="text-sm leading-sm sc-11af4f97-3 jXSgQY" data-id="TextBody">% Change</span><div class="sc-c0dd234a-0 sc-630fc9ab-0 gUjWRO bNkKFC"><i class="material-symbols-outlined cursor-pointer" translate="no" data-id="Icon" style="font-size: 16px; font-variation-settings: &quot;FILL&quot; 0, &quot;wght&quot; 400, &quot;GRAD&quot; 0, &quot;opsz&quot; 14;">unfold_more</i></div></button></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-163e4111-0 cyRNqz hFSujt"><button class="inline-flex items-center border-0 bg-inherit font-[inherit] text-[100%] sc-dd7510c8-0 cFKxd" type="button" data-id="UnstyledButton"><span class="text-sm leading-sm sc-11af4f97-3 jXSgQY" data-id="TextBody">Floor price</span><div class="sc-c0dd234a-0 sc-630fc9ab-0 gUjWRO bNkKFC"><i class="material-symbols-outlined cursor-pointer" translate="no" data-id="Icon" style="font-size: 16px; font-variation-settings: &quot;FILL&quot; 0, &quot;wght&quot; 400, &quot;GRAD&quot; 0, &quot;opsz&quot; 14;">unfold_more</i></div></button></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-163e4111-0 ebaotn hFSujt"><button class="inline-flex items-center border-0 bg-inherit font-[inherit] text-[100%] sc-dd7510c8-0 cFKxd" type="button" data-id="UnstyledButton"><span class="text-sm leading-sm sc-11af4f97-3 jXSgQY" data-id="TextBody">Sales</span><div class="sc-c0dd234a-0 sc-630fc9ab-0 gUjWRO bNkKFC"><i class="material-symbols-outlined cursor-pointer" translate="no" data-id="Icon" style="font-size: 16px; font-variation-settings: &quot;FILL&quot; 0, &quot;wght&quot; 400, &quot;GRAD&quot; 0, &quot;opsz&quot; 14;">unfold_more</i></div></button></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-163e4111-0 cyRNqz emIuUE"><button class="inline-flex items-center border-0 bg-inherit font-[inherit] text-[100%] sc-dd7510c8-0 cFKxd" type="button" data-id="UnstyledButton"><span class="text-sm leading-sm sc-11af4f97-3 jXSgQY" data-id="TextBody">% Unique owners</span><div class="sc-c0dd234a-0 sc-630fc9ab-0 gUjWRO bNkKFC"><i class="material-symbols-outlined cursor-pointer" translate="no" data-id="Icon" style="font-size: 16px; font-variation-settings: &quot;FILL&quot; 0, &quot;wght&quot; 400, &quot;GRAD&quot; 0, &quot;opsz&quot; 14;">unfold_more</i></div></button></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-163e4111-0 cyRNqz emIuUE"><button class="inline-flex items-center border-0 bg-inherit font-[inherit] text-[100%] sc-dd7510c8-0 cFKxd" type="button" data-id="UnstyledButton"><span class="text-sm leading-sm sc-11af4f97-3 jXSgQY" data-id="TextBody">% Items listed</span><div class="sc-c0dd234a-0 sc-630fc9ab-0 gUjWRO bNkKFC"><i class="material-symbols-outlined cursor-pointer" translate="no" data-id="Icon" style="font-size: 16px; font-variation-settings: &quot;FILL&quot; 0, &quot;wght&quot; 400, &quot;GRAD&quot; 0, &quot;opsz&quot; 14;">unfold_more</i></div></button></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div class="sc-c0dd234a-0 ghHIui"></div></div></div></div></div>

# %%
columns_header = soup.find_all('div', class_= "sc-c0dd234a-0 sc-630fc9ab-0 sc-4a4bbf51-0 egFVWu bNkKFC hPOmqI sc-163e4111-1 ia-Dfdl")

# %%
print(columns_header)
# Out:
# [<div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-4a4bbf51-0 egFVWu bNkKFC hPOmqI sc-163e4111-1 ia-Dfdl"><div class="sc-c0dd234a-0 sc-4a4bbf51-1 bpSPqV iwDeCi"><div class="flex justify-between sticky z-[1] h-full w-full items-center overflow-hidden border-none" style="top: 72px;"><div class="sc-c0dd234a-0 sc-24610f1f-0 sc-163e4111-0 dvzgPY hFSujt" theme="[object Object]"><div class="sc-c0dd234a-0 copoim"><span class="text-sm leading-sm text-secondary" data-id="TextBody">#</span></div><span class="text-sm leading-sm sc-11af4f97-2 hGwLac" data-id="TextBody">Collection</span></div><div class="sc-c0dd234a-0 sc-24610f1f-0 sc-163e4111-0 cyRNqz hFSujt" theme="[object Object]"><button class="inline-flex items-center border-0 bg-inherit font-[inherit] text-[100%] sc-dd7510c8-0 bePMuJ" data-id="UnstyledButton" type="button"><span class="text-sm leading-sm sc-11af4f97-4 hhVWHy" data-id="TextBody">Volume</span><div class="sc-c0dd234a-0 sc-630fc9ab-0 gUjWRO bNkKFC"><i class="material-symbols-outlined c
# ...

# %% [markdown]
# Collection Titles

# %%
Hashtag = soup.find('span', class_ = 'text-sm leading-sm text-secondary').text

# %%
Collection = soup.find('span', class_ ='text-sm leading-sm sc-11af4f97-2 hGwLac').text

# %%
Volume = soup.find('span', class_ ='text-sm leading-sm sc-11af4f97-4 hhVWHy').text

# %%
data = {
    '#': [Hashtag],
    'Collection': [Collection],
    'Volume': [Volume],
}

# %%
df = pd.DataFrame(columns = data)

# %%
df
# Out:
# Empty DataFrame
# Columns: [#, Collection, Volume]
# Index: []

# %% [markdown]
# Column Data

# %%
# <div role="table" tabindex="0" style="position: relative; width: 100%; max-width: 100%; height: 8956px; max-height: 8956px;"><div style="top: 616px; left: 0px; width: 1284px; writing-mode: horizontal-tb; position: absolute;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="/collection/azuki" role="row"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 kOZver"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">8</div></span></div><div class="sc-c0dd234a-0 fRinzB" aria-expanded="false"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: absolute; inset: 0px;"><img alt="Collection Image" sizes="64px" srcset="https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=48 48w, https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=64 64w, https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=128 128w, https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=256 256w, https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=384 384w, https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=512 512w, https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=640 640w, https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=750 750w, https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=828 828w, https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=1080 1080w, https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=1200 1200w, https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=1920 1920w, https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=2048 2048w, https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=3840 3840w" src="https://i.seadn.io/gae/H8jOCJuQokNqGBpkBN5wk1oZwO7LM8bNnrHCaekV2nKjnCqw6UB5oaH8XyNeBDj6bA_n1mjejzhFQUP3O1NfjFLHr3FOaeHcTOOT?auto=format&amp;dpr=1&amp;w=3840" decoding="async" data-nimg="fill" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover;"></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full"><div class="sc-c0dd234a-0 sc-cac1b17-3 ckCQsp hEVFmv"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC w-full"><span class="text-md leading-md font-semibold m-0 text-primary" data-id="TextBody" style="max-width: 500px;"><div class="sc-48082a-0 bguyED" tabindex="-1">Azuki</div></span><div class="sc-85796277-0 dfIUJZ" data-testid="verification-icon"><div aria-hidden="true" class="VerificationIcon--icon"><svg aria-label="verified-icon" class="sc-9c65691d-0 hDXJCP" fill="none" viewBox="0 0 30 30"><path d="M13.474 2.80108C14.2729 1.85822 15.7271 1.85822 16.526 2.80108L17.4886 3.9373C17.9785 4.51548 18.753 4.76715 19.4892 4.58733L20.9358 4.23394C22.1363 3.94069 23.3128 4.79547 23.4049 6.0278L23.5158 7.51286C23.5723 8.26854 24.051 8.92742 24.7522 9.21463L26.1303 9.77906C27.2739 10.2474 27.7233 11.6305 27.0734 12.6816L26.2903 13.9482C25.8918 14.5928 25.8918 15.4072 26.2903 16.0518L27.0734 17.3184C27.7233 18.3695 27.2739 19.7526 26.1303 20.2209L24.7522 20.7854C24.051 21.0726 23.5723 21.7315 23.5158 22.4871L23.4049 23.9722C23.3128 25.2045 22.1363 26.0593 20.9358 25.7661L19.4892 25.4127C18.753 25.2328 17.9785 25.4845 17.4886 26.0627L16.526 27.1989C15.7271 28.1418 14.2729 28.1418 13.474 27.1989L12.5114 26.0627C12.0215 25.4845 11.247 25.2328 10.5108 25.4127L9.06418 25.7661C7.86371 26.0593 6.6872 25.2045 6.59513 23.9722L6.48419 22.4871C6.42773 21.7315 5.94903 21.0726 5.24777 20.7854L3.86969 20.2209C2.72612 19.7526 2.27673 18.3695 2.9266 17.3184L3.70973 16.0518C4.10824 15.4072 4.10824 14.5928 3.70973 13.9482L2.9266 12.6816C2.27673 11.6305 2.72612 10.2474 3.86969 9.77906L5.24777 9.21463C5.94903 8.92742 6.42773 8.26854 6.48419 7.51286L6.59513 6.0278C6.6872 4.79547 7.86371 3.94069 9.06418 4.23394L10.5108 4.58733C11.247 4.76715 12.0215 4.51548 12.5114 3.9373L13.474 2.80108Z" class="sc-9c65691d-1 Sxbrk"></path><path d="M13.5 17.625L10.875 15L10 15.875L13.5 19.375L21 11.875L20.125 11L13.5 17.625Z" fill="white" stroke="white"></path></svg></div></div></div></div></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">592 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold text-red-2" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">-67%</div></span></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">4.20 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 hhAa-dT cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">143</div></span></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">43%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">4,261 owners</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">2%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">163 of 10,000</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div aria-label="Add to watchlist" data-testid="rankings-watchlist-button" role="button" tabindex="0" class="sc-4d608641-1 bKkxtp"><svg class="sc-4d608641-3 flTrwJ" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.6,3.9l2.2,4.4c0.1,0.2,0.3,0.4,0.6,0.4l4.9,0.7c0.6,0.1,0.8,0.8,0.4,1.2l-3.6,3.4c-0.2,0.2-0.3,0.4-0.2,0.6  l0.8,4.9c0.1,0.6-0.5,1.1-1.1,0.8l-4.4-2.3c-0.2-0.1-0.5-0.1-0.7,0l-4.4,2.3c-0.5,0.3-1.2-0.2-1.1-0.8L7,14.8c0-0.2,0-0.5-0.2-0.6  l-3.6-3.4C2.8,10.3,3,9.5,3.6,9.4l4.9-0.7c0.2,0,0.4-0.2,0.6-0.4l2.2-4.4C11.6,3.4,12.4,3.4,12.6,3.9z" fill="none" stroke="currentColor" stroke-miterlimit="10" stroke-width="2.5"></path></svg></div></div></a></div></div><div style="top: 968px; left: 0px; width: 1284px; writing-mode: horizontal-tb; position: absolute;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="/collection/otherdeed-expanded" role="row"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 kOZver"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">12</div></span></div><div class="sc-c0dd234a-0 fRinzB" aria-expanded="false"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: absolute; inset: 0px;"><img alt="Collection Image" sizes="64px" srcset="https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=48 48w, https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=64 64w, https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=128 128w, https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=256 256w, https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=384 384w, https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=512 512w, https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=640 640w, https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=750 750w, https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=828 828w, https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=1080 1080w, https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=1200 1200w, https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=1920 1920w, https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=2048 2048w, https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=3840 3840w" src="https://i.seadn.io/gcs/files/9583ab4792a83cd81d5075b59514a34a.png?auto=format&amp;dpr=1&amp;w=3840" decoding="async" data-nimg="fill" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover;"></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full"><div class="sc-c0dd234a-0 sc-cac1b17-3 ckCQsp hEVFmv"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC w-full"><span class="text-md leading-md font-semibold m-0 text-primary" data-id="TextBody" style="max-width: 500px;"><div class="sc-48082a-0 bguyED" tabindex="-1">Otherdeed Expanded</div></span><div class="sc-85796277-0 dfIUJZ" data-testid="verification-icon"><div aria-hidden="true" class="VerificationIcon--icon"><svg aria-label="verified-icon" class="sc-9c65691d-0 hDXJCP" fill="none" viewBox="0 0 30 30"><path d="M13.474 2.80108C14.2729 1.85822 15.7271 1.85822 16.526 2.80108L17.4886 3.9373C17.9785 4.51548 18.753 4.76715 19.4892 4.58733L20.9358 4.23394C22.1363 3.94069 23.3128 4.79547 23.4049 6.0278L23.5158 7.51286C23.5723 8.26854 24.051 8.92742 24.7522 9.21463L26.1303 9.77906C27.2739 10.2474 27.7233 11.6305 27.0734 12.6816L26.2903 13.9482C25.8918 14.5928 25.8918 15.4072 26.2903 16.0518L27.0734 17.3184C27.7233 18.3695 27.2739 19.7526 26.1303 20.2209L24.7522 20.7854C24.051 21.0726 23.5723 21.7315 23.5158 22.4871L23.4049 23.9722C23.3128 25.2045 22.1363 26.0593 20.9358 25.7661L19.4892 25.4127C18.753 25.2328 17.9785 25.4845 17.4886 26.0627L16.526 27.1989C15.7271 28.1418 14.2729 28.1418 13.474 27.1989L12.5114 26.0627C12.0215 25.4845 11.247 25.2328 10.5108 25.4127L9.06418 25.7661C7.86371 26.0593 6.6872 25.2045 6.59513 23.9722L6.48419 22.4871C6.42773 21.7315 5.94903 21.0726 5.24777 20.7854L3.86969 20.2209C2.72612 19.7526 2.27673 18.3695 2.9266 17.3184L3.70973 16.0518C4.10824 15.4072 4.10824 14.5928 3.70973 13.9482L2.9266 12.6816C2.27673 11.6305 2.72612 10.2474 3.86969 9.77906L5.24777 9.21463C5.94903 8.92742 6.42773 8.26854 6.48419 7.51286L6.59513 6.0278C6.6872 4.79547 7.86371 3.94069 9.06418 4.23394L10.5108 4.58733C11.247 4.76715 12.0215 4.51548 12.5114 3.9373L13.474 2.80108Z" class="sc-9c65691d-1 Sxbrk"></path><path d="M13.5 17.625L10.875 15L10 15.875L13.5 19.375L21 11.875L20.125 11L13.5 17.625Z" fill="white" stroke="white"></path></svg></div></div></div></div></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">367 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold text-green-2" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">+27%</div></span></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">0.27 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 hhAa-dT cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">805</div></span></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">27%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">13,569 owners</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">2%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">962 of 50,825</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div aria-label="Add to watchlist" data-testid="rankings-watchlist-button" role="button" tabindex="0" class="sc-4d608641-1 bKkxtp"><svg class="sc-4d608641-3 flTrwJ" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.6,3.9l2.2,4.4c0.1,0.2,0.3,0.4,0.6,0.4l4.9,0.7c0.6,0.1,0.8,0.8,0.4,1.2l-3.6,3.4c-0.2,0.2-0.3,0.4-0.2,0.6  l0.8,4.9c0.1,0.6-0.5,1.1-1.1,0.8l-4.4-2.3c-0.2-0.1-0.5-0.1-0.7,0l-4.4,2.3c-0.5,0.3-1.2-0.2-1.1-0.8L7,14.8c0-0.2,0-0.5-0.2-0.6  l-3.6-3.4C2.8,10.3,3,9.5,3.6,9.4l4.9-0.7c0.2,0,0.4-0.2,0.6-0.4l2.2-4.4C11.6,3.4,12.4,3.4,12.6,3.9z" fill="none" stroke="currentColor" stroke-miterlimit="10" stroke-width="2.5"></path></svg></div></div></a></div></div><div style="top: 1320px; left: 0px; width: 1284px; writing-mode: horizontal-tb; position: absolute;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="/collection/otherdeed" role="row"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 kOZver"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">16</div></span></div><div class="sc-c0dd234a-0 fRinzB" aria-expanded="false"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: absolute; inset: 0px;"><img alt="Collection Image" src="..." decoding="async" data-nimg="fill" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover;"><noscript></noscript></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full"><div class="sc-c0dd234a-0 sc-cac1b17-3 ckCQsp hEVFmv"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC w-full"><span class="text-md leading-md font-semibold m-0 text-primary" data-id="TextBody" style="max-width: 500px;"><div class="sc-48082a-0 bguyED" tabindex="-1">Otherdeed for Otherside</div></span><div class="sc-85796277-0 dfIUJZ" data-testid="verification-icon"><div aria-hidden="true" class="VerificationIcon--icon"><svg aria-label="verified-icon" class="sc-9c65691d-0 hDXJCP" fill="none" viewBox="0 0 30 30"><path d="M13.474 2.80108C14.2729 1.85822 15.7271 1.85822 16.526 2.80108L17.4886 3.9373C17.9785 4.51548 18.753 4.76715 19.4892 4.58733L20.9358 4.23394C22.1363 3.94069 23.3128 4.79547 23.4049 6.0278L23.5158 7.51286C23.5723 8.26854 24.051 8.92742 24.7522 9.21463L26.1303 9.77906C27.2739 10.2474 27.7233 11.6305 27.0734 12.6816L26.2903 13.9482C25.8918 14.5928 25.8918 15.4072 26.2903 16.0518L27.0734 17.3184C27.7233 18.3695 27.2739 19.7526 26.1303 20.2209L24.7522 20.7854C24.051 21.0726 23.5723 21.7315 23.5158 22.4871L23.4049 23.9722C23.3128 25.2045 22.1363 26.0593 20.9358 25.7661L19.4892 25.4127C18.753 25.2328 17.9785 25.4845 17.4886 26.0627L16.526 27.1989C15.7271 28.1418 14.2729 28.1418 13.474 27.1989L12.5114 26.0627C12.0215 25.4845 11.247 25.2328 10.5108 25.4127L9.06418 25.7661C7.86371 26.0593 6.6872 25.2045 6.59513 23.9722L6.48419 22.4871C6.42773 21.7315 5.94903 21.0726 5.24777 20.7854L3.86969 20.2209C2.72612 19.7526 2.27673 18.3695 2.9266 17.3184L3.70973 16.0518C4.10824 15.4072 4.10824 14.5928 3.70973 13.9482L2.9266 12.6816C2.27673 11.6305 2.72612 10.2474 3.86969 9.77906L5.24777 9.21463C5.94903 8.92742 6.42773 8.26854 6.48419 7.51286L6.59513 6.0278C6.6872 4.79547 7.86371 3.94069 9.06418 4.23394L10.5108 4.58733C11.247 4.76715 12.0215 4.51548 12.5114 3.9373L13.474 2.80108Z" class="sc-9c65691d-1 Sxbrk"></path><path d="M13.5 17.625L10.875 15L10 15.875L13.5 19.375L21 11.875L20.125 11L13.5 17.625Z" fill="white" stroke="white"></path></svg></div></div></div></div></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">337 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold text-red-2" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">-14%</div></span></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">0.65 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 hhAa-dT cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">448</div></span></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">33%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">16,468 owners</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">0.92%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">451 of 49,174</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div aria-label="Add to watchlist" data-testid="rankings-watchlist-button" role="button" tabindex="0" class="sc-4d608641-1 bKkxtp"><svg class="sc-4d608641-3 flTrwJ" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.6,3.9l2.2,4.4c0.1,0.2,0.3,0.4,0.6,0.4l4.9,0.7c0.6,0.1,0.8,0.8,0.4,1.2l-3.6,3.4c-0.2,0.2-0.3,0.4-0.2,0.6  l0.8,4.9c0.1,0.6-0.5,1.1-1.1,0.8l-4.4-2.3c-0.2-0.1-0.5-0.1-0.7,0l-4.4,2.3c-0.5,0.3-1.2-0.2-1.1-0.8L7,14.8c0-0.2,0-0.5-0.2-0.6  l-3.6-3.4C2.8,10.3,3,9.5,3.6,9.4l4.9-0.7c0.2,0,0.4-0.2,0.6-0.4l2.2-4.4C11.6,3.4,12.4,3.4,12.6,3.9z" fill="none" stroke="currentColor" stroke-miterlimit="10" stroke-width="2.5"></path></svg></div></div></a></div></div><div style="top: 1496px; left: 0px; width: 1284px; writing-mode: horizontal-tb; position: absolute;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="/collection/chromie-squiggle-by-snowfro" role="row"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 kOZver"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">18</div></span></div><div class="sc-c0dd234a-0 fRinzB" aria-expanded="false"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: absolute; inset: 0px;"><img alt="Collection Image" src="..." decoding="async" data-nimg="fill" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover;"><noscript></noscript></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full"><div class="sc-c0dd234a-0 sc-cac1b17-3 ckCQsp hEVFmv"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC w-full"><span class="text-md leading-md font-semibold m-0 text-primary" data-id="TextBody" style="max-width: 500px;"><div class="sc-48082a-0 bguyED" tabindex="-1">Chromie Squiggle by Snowfro</div></span><div class="sc-85796277-0 dfIUJZ" data-testid="verification-icon"><div aria-hidden="true" class="VerificationIcon--icon"><svg aria-label="verified-icon" class="sc-9c65691d-0 hDXJCP" fill="none" viewBox="0 0 30 30"><path d="M13.474 2.80108C14.2729 1.85822 15.7271 1.85822 16.526 2.80108L17.4886 3.9373C17.9785 4.51548 18.753 4.76715 19.4892 4.58733L20.9358 4.23394C22.1363 3.94069 23.3128 4.79547 23.4049 6.0278L23.5158 7.51286C23.5723 8.26854 24.051 8.92742 24.7522 9.21463L26.1303 9.77906C27.2739 10.2474 27.7233 11.6305 27.0734 12.6816L26.2903 13.9482C25.8918 14.5928 25.8918 15.4072 26.2903 16.0518L27.0734 17.3184C27.7233 18.3695 27.2739 19.7526 26.1303 20.2209L24.7522 20.7854C24.051 21.0726 23.5723 21.7315 23.5158 22.4871L23.4049 23.9722C23.3128 25.2045 22.1363 26.0593 20.9358 25.7661L19.4892 25.4127C18.753 25.2328 17.9785 25.4845 17.4886 26.0627L16.526 27.1989C15.7271 28.1418 14.2729 28.1418 13.474 27.1989L12.5114 26.0627C12.0215 25.4845 11.247 25.2328 10.5108 25.4127L9.06418 25.7661C7.86371 26.0593 6.6872 25.2045 6.59513 23.9722L6.48419 22.4871C6.42773 21.7315 5.94903 21.0726 5.24777 20.7854L3.86969 20.2209C2.72612 19.7526 2.27673 18.3695 2.9266 17.3184L3.70973 16.0518C4.10824 15.4072 4.10824 14.5928 3.70973 13.9482L2.9266 12.6816C2.27673 11.6305 2.72612 10.2474 3.86969 9.77906L5.24777 9.21463C5.94903 8.92742 6.42773 8.26854 6.48419 7.51286L6.59513 6.0278C6.6872 4.79547 7.86371 3.94069 9.06418 4.23394L10.5108 4.58733C11.247 4.76715 12.0215 4.51548 12.5114 3.9373L13.474 2.80108Z" class="sc-9c65691d-1 Sxbrk"></path><path d="M13.5 17.625L10.875 15L10 15.875L13.5 19.375L21 11.875L20.125 11L13.5 17.625Z" fill="white" stroke="white"></path></svg></div></div></div></div></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">259 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold text-green-2" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">+29%</div></span></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">9.69 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 hhAa-dT cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">25</div></span></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">29%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">2,926 owners</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">2%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">150 of 9,993</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div aria-label="Add to watchlist" data-testid="rankings-watchlist-button" role="button" tabindex="0" class="sc-4d608641-1 bKkxtp"><svg class="sc-4d608641-3 flTrwJ" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.6,3.9l2.2,4.4c0.1,0.2,0.3,0.4,0.6,0.4l4.9,0.7c0.6,0.1,0.8,0.8,0.4,1.2l-3.6,3.4c-0.2,0.2-0.3,0.4-0.2,0.6  l0.8,4.9c0.1,0.6-0.5,1.1-1.1,0.8l-4.4-2.3c-0.2-0.1-0.5-0.1-0.7,0l-4.4,2.3c-0.5,0.3-1.2-0.2-1.1-0.8L7,14.8c0-0.2,0-0.5-0.2-0.6  l-3.6-3.4C2.8,10.3,3,9.5,3.6,9.4l4.9-0.7c0.2,0,0.4-0.2,0.6-0.4l2.2-4.4C11.6,3.4,12.4,3.4,12.6,3.9z" fill="none" stroke="currentColor" stroke-miterlimit="10" stroke-width="2.5"></path></svg></div></div></a></div></div><div style="top: 1672px; left: 0px; width: 1284px; writing-mode: horizontal-tb; position: absolute;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="/collection/doodles-official" role="row"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 kOZver"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">20</div></span></div><div class="sc-c0dd234a-0 fRinzB" aria-expanded="false"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: absolute; inset: 0px;"><img alt="Collection Image" src="..." decoding="async" data-nimg="fill" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover;"><noscript></noscript></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full"><div class="sc-c0dd234a-0 sc-cac1b17-3 ckCQsp hEVFmv"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC w-full"><span class="text-md leading-md font-semibold m-0 text-primary" data-id="TextBody" style="max-width: 500px;"><div class="sc-48082a-0 bguyED" tabindex="-1">Doodles</div></span><div class="sc-85796277-0 dfIUJZ" data-testid="verification-icon"><div aria-hidden="true" class="VerificationIcon--icon"><svg aria-label="verified-icon" class="sc-9c65691d-0 hDXJCP" fill="none" viewBox="0 0 30 30"><path d="M13.474 2.80108C14.2729 1.85822 15.7271 1.85822 16.526 2.80108L17.4886 3.9373C17.9785 4.51548 18.753 4.76715 19.4892 4.58733L20.9358 4.23394C22.1363 3.94069 23.3128 4.79547 23.4049 6.0278L23.5158 7.51286C23.5723 8.26854 24.051 8.92742 24.7522 9.21463L26.1303 9.77906C27.2739 10.2474 27.7233 11.6305 27.0734 12.6816L26.2903 13.9482C25.8918 14.5928 25.8918 15.4072 26.2903 16.0518L27.0734 17.3184C27.7233 18.3695 27.2739 19.7526 26.1303 20.2209L24.7522 20.7854C24.051 21.0726 23.5723 21.7315 23.5158 22.4871L23.4049 23.9722C23.3128 25.2045 22.1363 26.0593 20.9358 25.7661L19.4892 25.4127C18.753 25.2328 17.9785 25.4845 17.4886 26.0627L16.526 27.1989C15.7271 28.1418 14.2729 28.1418 13.474 27.1989L12.5114 26.0627C12.0215 25.4845 11.247 25.2328 10.5108 25.4127L9.06418 25.7661C7.86371 26.0593 6.6872 25.2045 6.59513 23.9722L6.48419 22.4871C6.42773 21.7315 5.94903 21.0726 5.24777 20.7854L3.86969 20.2209C2.72612 19.7526 2.27673 18.3695 2.9266 17.3184L3.70973 16.0518C4.10824 15.4072 4.10824 14.5928 3.70973 13.9482L2.9266 12.6816C2.27673 11.6305 2.72612 10.2474 3.86969 9.77906L5.24777 9.21463C5.94903 8.92742 6.42773 8.26854 6.48419 7.51286L6.59513 6.0278C6.6872 4.79547 7.86371 3.94069 9.06418 4.23394L10.5108 4.58733C11.247 4.76715 12.0215 4.51548 12.5114 3.9373L13.474 2.80108Z" class="sc-9c65691d-1 Sxbrk"></path><path d="M13.5 17.625L10.875 15L10 15.875L13.5 19.375L21 11.875L20.125 11L13.5 17.625Z" fill="white" stroke="white"></path></svg></div></div></div></div></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">249 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold text-green-2" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">+109%</div></span></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">1.34 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 hhAa-dT cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">197</div></span></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">56%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">5,605 owners</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">2%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">202 of 9,998</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div aria-label="Add to watchlist" data-testid="rankings-watchlist-button" role="button" tabindex="0" class="sc-4d608641-1 bKkxtp"><svg class="sc-4d608641-3 flTrwJ" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.6,3.9l2.2,4.4c0.1,0.2,0.3,0.4,0.6,0.4l4.9,0.7c0.6,0.1,0.8,0.8,0.4,1.2l-3.6,3.4c-0.2,0.2-0.3,0.4-0.2,0.6  l0.8,4.9c0.1,0.6-0.5,1.1-1.1,0.8l-4.4-2.3c-0.2-0.1-0.5-0.1-0.7,0l-4.4,2.3c-0.5,0.3-1.2-0.2-1.1-0.8L7,14.8c0-0.2,0-0.5-0.2-0.6  l-3.6-3.4C2.8,10.3,3,9.5,3.6,9.4l4.9-0.7c0.2,0,0.4-0.2,0.6-0.4l2.2-4.4C11.6,3.4,12.4,3.4,12.6,3.9z" fill="none" stroke="currentColor" stroke-miterlimit="10" stroke-width="2.5"></path></svg></div></div></a></div></div><div style="top: 1760px; left: 0px; width: 1284px; writing-mode: horizontal-tb; position: absolute;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="/collection/thecaptainz" role="row"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 kOZver"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">21</div></span></div><div class="sc-c0dd234a-0 fRinzB" aria-expanded="false"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: absolute; inset: 0px;"><img alt="Collection Image" sizes="64px" srcset="https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=48 48w, https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=64 64w, https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=128 128w, https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=256 256w, https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=384 384w, https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=512 512w, https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=640 640w, https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=750 750w, https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=828 828w, https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=1080 1080w, https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=1200 1200w, https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=1920 1920w, https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=2048 2048w, https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=3840 3840w" src="https://i.seadn.io/gcs/files/6df4d75778066bce740050615bc84e21.png?auto=format&amp;dpr=1&amp;w=3840" decoding="async" data-nimg="fill" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover;"></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full"><div class="sc-c0dd234a-0 sc-cac1b17-3 ckCQsp hEVFmv"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC w-full"><span class="text-md leading-md font-semibold m-0 text-primary" data-id="TextBody" style="max-width: 500px;"><div class="sc-48082a-0 bguyED" tabindex="-1">The Captainz</div></span><div class="sc-85796277-0 dfIUJZ" data-testid="verification-icon"><div aria-hidden="true" class="VerificationIcon--icon"><svg aria-label="verified-icon" class="sc-9c65691d-0 hDXJCP" fill="none" viewBox="0 0 30 30"><path d="M13.474 2.80108C14.2729 1.85822 15.7271 1.85822 16.526 2.80108L17.4886 3.9373C17.9785 4.51548 18.753 4.76715 19.4892 4.58733L20.9358 4.23394C22.1363 3.94069 23.3128 4.79547 23.4049 6.0278L23.5158 7.51286C23.5723 8.26854 24.051 8.92742 24.7522 9.21463L26.1303 9.77906C27.2739 10.2474 27.7233 11.6305 27.0734 12.6816L26.2903 13.9482C25.8918 14.5928 25.8918 15.4072 26.2903 16.0518L27.0734 17.3184C27.7233 18.3695 27.2739 19.7526 26.1303 20.2209L24.7522 20.7854C24.051 21.0726 23.5723 21.7315 23.5158 22.4871L23.4049 23.9722C23.3128 25.2045 22.1363 26.0593 20.9358 25.7661L19.4892 25.4127C18.753 25.2328 17.9785 25.4845 17.4886 26.0627L16.526 27.1989C15.7271 28.1418 14.2729 28.1418 13.474 27.1989L12.5114 26.0627C12.0215 25.4845 11.247 25.2328 10.5108 25.4127L9.06418 25.7661C7.86371 26.0593 6.6872 25.2045 6.59513 23.9722L6.48419 22.4871C6.42773 21.7315 5.94903 21.0726 5.24777 20.7854L3.86969 20.2209C2.72612 19.7526 2.27673 18.3695 2.9266 17.3184L3.70973 16.0518C4.10824 15.4072 4.10824 14.5928 3.70973 13.9482L2.9266 12.6816C2.27673 11.6305 2.72612 10.2474 3.86969 9.77906L5.24777 9.21463C5.94903 8.92742 6.42773 8.26854 6.48419 7.51286L6.59513 6.0278C6.6872 4.79547 7.86371 3.94069 9.06418 4.23394L10.5108 4.58733C11.247 4.76715 12.0215 4.51548 12.5114 3.9373L13.474 2.80108Z" class="sc-9c65691d-1 Sxbrk"></path><path d="M13.5 17.625L10.875 15L10 15.875L13.5 19.375L21 11.875L20.125 11L13.5 17.625Z" fill="white" stroke="white"></path></svg></div></div></div></div></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">210 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold text-red-2" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">-49%</div></span></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">3.50 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 hhAa-dT cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">57</div></span></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">42%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">4,182 owners</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">0.52%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">52 of 9,999</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div aria-label="Add to watchlist" data-testid="rankings-watchlist-button" role="button" tabindex="0" class="sc-4d608641-1 bKkxtp"><svg class="sc-4d608641-3 flTrwJ" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.6,3.9l2.2,4.4c0.1,0.2,0.3,0.4,0.6,0.4l4.9,0.7c0.6,0.1,0.8,0.8,0.4,1.2l-3.6,3.4c-0.2,0.2-0.3,0.4-0.2,0.6  l0.8,4.9c0.1,0.6-0.5,1.1-1.1,0.8l-4.4-2.3c-0.2-0.1-0.5-0.1-0.7,0l-4.4,2.3c-0.5,0.3-1.2-0.2-1.1-0.8L7,14.8c0-0.2,0-0.5-0.2-0.6  l-3.6-3.4C2.8,10.3,3,9.5,3.6,9.4l4.9-0.7c0.2,0,0.4-0.2,0.6-0.4l2.2-4.4C11.6,3.4,12.4,3.4,12.6,3.9z" fill="none" stroke="currentColor" stroke-miterlimit="10" stroke-width="2.5"></path></svg></div></div></a></div></div><div style="top: 1848px; left: 0px; width: 1284px; writing-mode: horizontal-tb; position: absolute;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="/collection/opepen-edition" role="row"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 kOZver"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">22</div></span></div><div class="sc-c0dd234a-0 fRinzB" aria-expanded="false"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: absolute; inset: 0px;"><img alt="Collection Image" sizes="64px" srcset="https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=48 48w, https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=64 64w, https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=128 128w, https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=256 256w, https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=384 384w, https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=512 512w, https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=640 640w, https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=750 750w, https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=828 828w, https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=1080 1080w, https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=1200 1200w, https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=1920 1920w, https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=2048 2048w, https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=3840 3840w" src="https://i.seadn.io/gcs/files/b1c9ed2e584b4f6e418bf1ca15311844.jpg?auto=format&amp;dpr=1&amp;w=3840" decoding="async" data-nimg="fill" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover;"></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full"><div class="sc-c0dd234a-0 sc-cac1b17-3 ckCQsp hEVFmv"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC w-full"><span class="text-md leading-md font-semibold m-0 text-primary" data-id="TextBody" style="max-width: 500px;"><div class="sc-48082a-0 bguyED" tabindex="-1">Opepen Edition</div></span><div class="sc-85796277-0 dfIUJZ" data-testid="verification-icon"><div aria-hidden="true" class="VerificationIcon--icon"><svg aria-label="verified-icon" class="sc-9c65691d-0 hDXJCP" fill="none" viewBox="0 0 30 30"><path d="M13.474 2.80108C14.2729 1.85822 15.7271 1.85822 16.526 2.80108L17.4886 3.9373C17.9785 4.51548 18.753 4.76715 19.4892 4.58733L20.9358 4.23394C22.1363 3.94069 23.3128 4.79547 23.4049 6.0278L23.5158 7.51286C23.5723 8.26854 24.051 8.92742 24.7522 9.21463L26.1303 9.77906C27.2739 10.2474 27.7233 11.6305 27.0734 12.6816L26.2903 13.9482C25.8918 14.5928 25.8918 15.4072 26.2903 16.0518L27.0734 17.3184C27.7233 18.3695 27.2739 19.7526 26.1303 20.2209L24.7522 20.7854C24.051 21.0726 23.5723 21.7315 23.5158 22.4871L23.4049 23.9722C23.3128 25.2045 22.1363 26.0593 20.9358 25.7661L19.4892 25.4127C18.753 25.2328 17.9785 25.4845 17.4886 26.0627L16.526 27.1989C15.7271 28.1418 14.2729 28.1418 13.474 27.1989L12.5114 26.0627C12.0215 25.4845 11.247 25.2328 10.5108 25.4127L9.06418 25.7661C7.86371 26.0593 6.6872 25.2045 6.59513 23.9722L6.48419 22.4871C6.42773 21.7315 5.94903 21.0726 5.24777 20.7854L3.86969 20.2209C2.72612 19.7526 2.27673 18.3695 2.9266 17.3184L3.70973 16.0518C4.10824 15.4072 4.10824 14.5928 3.70973 13.9482L2.9266 12.6816C2.27673 11.6305 2.72612 10.2474 3.86969 9.77906L5.24777 9.21463C5.94903 8.92742 6.42773 8.26854 6.48419 7.51286L6.59513 6.0278C6.6872 4.79547 7.86371 3.94069 9.06418 4.23394L10.5108 4.58733C11.247 4.76715 12.0215 4.51548 12.5114 3.9373L13.474 2.80108Z" class="sc-9c65691d-1 Sxbrk"></path><path d="M13.5 17.625L10.875 15L10 15.875L13.5 19.375L21 11.875L20.125 11L13.5 17.625Z" fill="white" stroke="white"></path></svg></div></div></div></div></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">205 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold text-red-2" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">-50%</div></span></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">0.40 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 hhAa-dT cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">422</div></span></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">26%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">4,174 owners</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">3%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">423 of 16,000</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div aria-label="Add to watchlist" data-testid="rankings-watchlist-button" role="button" tabindex="0" class="sc-4d608641-1 bKkxtp"><svg class="sc-4d608641-3 flTrwJ" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.6,3.9l2.2,4.4c0.1,0.2,0.3,0.4,0.6,0.4l4.9,0.7c0.6,0.1,0.8,0.8,0.4,1.2l-3.6,3.4c-0.2,0.2-0.3,0.4-0.2,0.6  l0.8,4.9c0.1,0.6-0.5,1.1-1.1,0.8l-4.4-2.3c-0.2-0.1-0.5-0.1-0.7,0l-4.4,2.3c-0.5,0.3-1.2-0.2-1.1-0.8L7,14.8c0-0.2,0-0.5-0.2-0.6  l-3.6-3.4C2.8,10.3,3,9.5,3.6,9.4l4.9-0.7c0.2,0,0.4-0.2,0.6-0.4l2.2-4.4C11.6,3.4,12.4,3.4,12.6,3.9z" fill="none" stroke="currentColor" stroke-miterlimit="10" stroke-width="2.5"></path></svg></div></div></a></div></div><div style="top: 1584px; left: 0px; width: 1284px; writing-mode: horizontal-tb; position: absolute;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="/collection/fewoworld-fewos" role="row"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 kOZver"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">19</div></span></div><div class="sc-c0dd234a-0 fRinzB" aria-expanded="false"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: absolute; inset: 0px;"><img alt="Collection Image" src="..." decoding="async" data-nimg="fill" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover;"><noscript></noscript></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full"><div class="sc-c0dd234a-0 sc-cac1b17-3 ckCQsp hEVFmv"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC w-full"><span class="text-md leading-md font-semibold m-0 text-primary" data-id="TextBody" style="max-width: 500px;"><div class="sc-48082a-0 bguyED" tabindex="-1">FEWOCiOUS x FewoWorld: Fewos</div></span><div class="sc-85796277-0 dfIUJZ" data-testid="verification-icon"><div aria-hidden="true" class="VerificationIcon--icon"><svg aria-label="verified-icon" class="sc-9c65691d-0 hDXJCP" fill="none" viewBox="0 0 30 30"><path d="M13.474 2.80108C14.2729 1.85822 15.7271 1.85822 16.526 2.80108L17.4886 3.9373C17.9785 4.51548 18.753 4.76715 19.4892 4.58733L20.9358 4.23394C22.1363 3.94069 23.3128 4.79547 23.4049 6.0278L23.5158 7.51286C23.5723 8.26854 24.051 8.92742 24.7522 9.21463L26.1303 9.77906C27.2739 10.2474 27.7233 11.6305 27.0734 12.6816L26.2903 13.9482C25.8918 14.5928 25.8918 15.4072 26.2903 16.0518L27.0734 17.3184C27.7233 18.3695 27.2739 19.7526 26.1303 20.2209L24.7522 20.7854C24.051 21.0726 23.5723 21.7315 23.5158 22.4871L23.4049 23.9722C23.3128 25.2045 22.1363 26.0593 20.9358 25.7661L19.4892 25.4127C18.753 25.2328 17.9785 25.4845 17.4886 26.0627L16.526 27.1989C15.7271 28.1418 14.2729 28.1418 13.474 27.1989L12.5114 26.0627C12.0215 25.4845 11.247 25.2328 10.5108 25.4127L9.06418 25.7661C7.86371 26.0593 6.6872 25.2045 6.59513 23.9722L6.48419 22.4871C6.42773 21.7315 5.94903 21.0726 5.24777 20.7854L3.86969 20.2209C2.72612 19.7526 2.27673 18.3695 2.9266 17.3184L3.70973 16.0518C4.10824 15.4072 4.10824 14.5928 3.70973 13.9482L2.9266 12.6816C2.27673 11.6305 2.72612 10.2474 3.86969 9.77906L5.24777 9.21463C5.94903 8.92742 6.42773 8.26854 6.48419 7.51286L6.59513 6.0278C6.6872 4.79547 7.86371 3.94069 9.06418 4.23394L10.5108 4.58733C11.247 4.76715 12.0215 4.51548 12.5114 3.9373L13.474 2.80108Z" class="sc-9c65691d-1 Sxbrk"></path><path d="M13.5 17.625L10.875 15L10 15.875L13.5 19.375L21 11.875L20.125 11L13.5 17.625Z" fill="white" stroke="white"></path></svg></div></div></div></div></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">259 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold text-green-2" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">+1,127%</div></span></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">0.05 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 hhAa-dT cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">2,120</div></span></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">21%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">3,745 owners</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">4%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">793 of 18,000</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div aria-label="Add to watchlist" data-testid="rankings-watchlist-button" role="button" tabindex="0" class="sc-4d608641-1 bKkxtp"><svg class="sc-4d608641-3 flTrwJ" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.6,3.9l2.2,4.4c0.1,0.2,0.3,0.4,0.6,0.4l4.9,0.7c0.6,0.1,0.8,0.8,0.4,1.2l-3.6,3.4c-0.2,0.2-0.3,0.4-0.2,0.6  l0.8,4.9c0.1,0.6-0.5,1.1-1.1,0.8l-4.4-2.3c-0.2-0.1-0.5-0.1-0.7,0l-4.4,2.3c-0.5,0.3-1.2-0.2-1.1-0.8L7,14.8c0-0.2,0-0.5-0.2-0.6  l-3.6-3.4C2.8,10.3,3,9.5,3.6,9.4l4.9-0.7c0.2,0,0.4-0.2,0.6-0.4l2.2-4.4C11.6,3.4,12.4,3.4,12.6,3.9z" fill="none" stroke="currentColor" stroke-miterlimit="10" stroke-width="2.5"></path></svg></div></div></a></div></div><div style="top: 1408px; left: 0px; width: 1284px; writing-mode: horizontal-tb; position: absolute;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="/collection/lilpudgys" role="row"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 kOZver"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">17</div></span></div><div class="sc-c0dd234a-0 fRinzB" aria-expanded="false"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: absolute; inset: 0px;"><img alt="Collection Image" src="..." decoding="async" data-nimg="fill" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover;"><noscript></noscript></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full"><div class="sc-c0dd234a-0 sc-cac1b17-3 ckCQsp hEVFmv"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC w-full"><span class="text-md leading-md font-semibold m-0 text-primary" data-id="TextBody" style="max-width: 500px;"><div class="sc-48082a-0 bguyED" tabindex="-1">Lil Pudgys</div></span><div class="sc-85796277-0 dfIUJZ" data-testid="verification-icon"><div aria-hidden="true" class="VerificationIcon--icon"><svg aria-label="verified-icon" class="sc-9c65691d-0 hDXJCP" fill="none" viewBox="0 0 30 30"><path d="M13.474 2.80108C14.2729 1.85822 15.7271 1.85822 16.526 2.80108L17.4886 3.9373C17.9785 4.51548 18.753 4.76715 19.4892 4.58733L20.9358 4.23394C22.1363 3.94069 23.3128 4.79547 23.4049 6.0278L23.5158 7.51286C23.5723 8.26854 24.051 8.92742 24.7522 9.21463L26.1303 9.77906C27.2739 10.2474 27.7233 11.6305 27.0734 12.6816L26.2903 13.9482C25.8918 14.5928 25.8918 15.4072 26.2903 16.0518L27.0734 17.3184C27.7233 18.3695 27.2739 19.7526 26.1303 20.2209L24.7522 20.7854C24.051 21.0726 23.5723 21.7315 23.5158 22.4871L23.4049 23.9722C23.3128 25.2045 22.1363 26.0593 20.9358 25.7661L19.4892 25.4127C18.753 25.2328 17.9785 25.4845 17.4886 26.0627L16.526 27.1989C15.7271 28.1418 14.2729 28.1418 13.474 27.1989L12.5114 26.0627C12.0215 25.4845 11.247 25.2328 10.5108 25.4127L9.06418 25.7661C7.86371 26.0593 6.6872 25.2045 6.59513 23.9722L6.48419 22.4871C6.42773 21.7315 5.94903 21.0726 5.24777 20.7854L3.86969 20.2209C2.72612 19.7526 2.27673 18.3695 2.9266 17.3184L3.70973 16.0518C4.10824 15.4072 4.10824 14.5928 3.70973 13.9482L2.9266 12.6816C2.27673 11.6305 2.72612 10.2474 3.86969 9.77906L5.24777 9.21463C5.94903 8.92742 6.42773 8.26854 6.48419 7.51286L6.59513 6.0278C6.6872 4.79547 7.86371 3.94069 9.06418 4.23394L10.5108 4.58733C11.247 4.76715 12.0215 4.51548 12.5114 3.9373L13.474 2.80108Z" class="sc-9c65691d-1 Sxbrk"></path><path d="M13.5 17.625L10.875 15L10 15.875L13.5 19.375L21 11.875L20.125 11L13.5 17.625Z" fill="white" stroke="white"></path></svg></div></div></div></div></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">293 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold text-red-2" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">-22%</div></span></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">0.50 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 hhAa-dT cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">681</div></span></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">36%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">7,662 owners</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">2%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">523 of 21,255</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div aria-label="Add to watchlist" data-testid="rankings-watchlist-button" role="button" tabindex="0" class="sc-4d608641-1 bKkxtp"><svg class="sc-4d608641-3 flTrwJ" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.6,3.9l2.2,4.4c0.1,0.2,0.3,0.4,0.6,0.4l4.9,0.7c0.6,0.1,0.8,0.8,0.4,1.2l-3.6,3.4c-0.2,0.2-0.3,0.4-0.2,0.6  l0.8,4.9c0.1,0.6-0.5,1.1-1.1,0.8l-4.4-2.3c-0.2-0.1-0.5-0.1-0.7,0l-4.4,2.3c-0.5,0.3-1.2-0.2-1.1-0.8L7,14.8c0-0.2,0-0.5-0.2-0.6  l-3.6-3.4C2.8,10.3,3,9.5,3.6,9.4l4.9-0.7c0.2,0,0.4-0.2,0.6-0.4l2.2-4.4C11.6,3.4,12.4,3.4,12.6,3.9z" fill="none" stroke="currentColor" stroke-miterlimit="10" stroke-width="2.5"></path></svg></div></div></a></div></div><div style="top: 1144px; left: 0px; width: 1284px; writing-mode: horizontal-tb; position: absolute;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="/collection/otherside-koda" role="row"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 kOZver"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">14</div></span></div><div class="sc-c0dd234a-0 fRinzB" aria-expanded="false"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: absolute; inset: 0px;"><img alt="Collection Image" sizes="64px" srcset="https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=48 48w, https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=64 64w, https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=128 128w, https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=256 256w, https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=384 384w, https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=512 512w, https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=640 640w, https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=750 750w, https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=828 828w, https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=1080 1080w, https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=1200 1200w, https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=1920 1920w, https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=2048 2048w, https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=3840 3840w" src="https://i.seadn.io/gcs/files/adeb11bcd531b77f55ce10c217e50841.jpg?auto=format&amp;dpr=1&amp;w=3840" decoding="async" data-nimg="fill" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover;"></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full"><div class="sc-c0dd234a-0 sc-cac1b17-3 ckCQsp hEVFmv"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC w-full"><span class="text-md leading-md font-semibold m-0 text-primary" data-id="TextBody" style="max-width: 500px;"><div class="sc-48082a-0 bguyED" tabindex="-1">Otherside Koda</div></span><div class="sc-85796277-0 dfIUJZ" data-testid="verification-icon"><div aria-hidden="true" class="VerificationIcon--icon"><svg aria-label="verified-icon" class="sc-9c65691d-0 hDXJCP" fill="none" viewBox="0 0 30 30"><path d="M13.474 2.80108C14.2729 1.85822 15.7271 1.85822 16.526 2.80108L17.4886 3.9373C17.9785 4.51548 18.753 4.76715 19.4892 4.58733L20.9358 4.23394C22.1363 3.94069 23.3128 4.79547 23.4049 6.0278L23.5158 7.51286C23.5723 8.26854 24.051 8.92742 24.7522 9.21463L26.1303 9.77906C27.2739 10.2474 27.7233 11.6305 27.0734 12.6816L26.2903 13.9482C25.8918 14.5928 25.8918 15.4072 26.2903 16.0518L27.0734 17.3184C27.7233 18.3695 27.2739 19.7526 26.1303 20.2209L24.7522 20.7854C24.051 21.0726 23.5723 21.7315 23.5158 22.4871L23.4049 23.9722C23.3128 25.2045 22.1363 26.0593 20.9358 25.7661L19.4892 25.4127C18.753 25.2328 17.9785 25.4845 17.4886 26.0627L16.526 27.1989C15.7271 28.1418 14.2729 28.1418 13.474 27.1989L12.5114 26.0627C12.0215 25.4845 11.247 25.2328 10.5108 25.4127L9.06418 25.7661C7.86371 26.0593 6.6872 25.2045 6.59513 23.9722L6.48419 22.4871C6.42773 21.7315 5.94903 21.0726 5.24777 20.7854L3.86969 20.2209C2.72612 19.7526 2.27673 18.3695 2.9266 17.3184L3.70973 16.0518C4.10824 15.4072 4.10824 14.5928 3.70973 13.9482L2.9266 12.6816C2.27673 11.6305 2.72612 10.2474 3.86969 9.77906L5.24777 9.21463C5.94903 8.92742 6.42773 8.26854 6.48419 7.51286L6.59513 6.0278C6.6872 4.79547 7.86371 3.94069 9.06418 4.23394L10.5108 4.58733C11.247 4.76715 12.0215 4.51548 12.5114 3.9373L13.474 2.80108Z" class="sc-9c65691d-1 Sxbrk"></path><path d="M13.5 17.625L10.875 15L10 15.875L13.5 19.375L21 11.875L20.125 11L13.5 17.625Z" fill="white" stroke="white"></path></svg></div></div></div></div></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">355 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold text-green-2" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">+7%</div></span></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">3.35 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 hhAa-dT cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">95</div></span></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">56%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">3,525 owners</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">2%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">135 of 6,312</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div aria-label="Add to watchlist" data-testid="rankings-watchlist-button" role="button" tabindex="0" class="sc-4d608641-1 bKkxtp"><svg class="sc-4d608641-3 flTrwJ" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.6,3.9l2.2,4.4c0.1,0.2,0.3,0.4,0.6,0.4l4.9,0.7c0.6,0.1,0.8,0.8,0.4,1.2l-3.6,3.4c-0.2,0.2-0.3,0.4-0.2,0.6  l0.8,4.9c0.1,0.6-0.5,1.1-1.1,0.8l-4.4-2.3c-0.2-0.1-0.5-0.1-0.7,0l-4.4,2.3c-0.5,0.3-1.2-0.2-1.1-0.8L7,14.8c0-0.2,0-0.5-0.2-0.6  l-3.6-3.4C2.8,10.3,3,9.5,3.6,9.4l4.9-0.7c0.2,0,0.4-0.2,0.6-0.4l2.2-4.4C11.6,3.4,12.4,3.4,12.6,3.9z" fill="none" stroke="currentColor" stroke-miterlimit="10" stroke-width="2.5"></path></svg></div></div></a></div></div><div style="top: 1232px; left: 0px; width: 1284px; writing-mode: horizontal-tb; position: absolute;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="/collection/winds-of-yawanawa" role="row"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 kOZver"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">15</div></span></div><div class="sc-c0dd234a-0 fRinzB" aria-expanded="false"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: absolute; inset: 0px;"><img alt="Collection Image" sizes="64px" srcset="https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=48 48w, https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=64 64w, https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=128 128w, https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=256 256w, https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=384 384w, https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=512 512w, https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=640 640w, https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=750 750w, https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=828 828w, https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=1080 1080w, https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=1200 1200w, https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=1920 1920w, https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=2048 2048w, https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=3840 3840w" src="https://i.seadn.io/gcs/files/98795786ed318c580e8438874c21603f.jpg?auto=format&amp;dpr=1&amp;w=3840" decoding="async" data-nimg="fill" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover;"></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full"><div class="sc-c0dd234a-0 sc-cac1b17-3 ckCQsp hEVFmv"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC w-full"><span class="text-md leading-md font-semibold m-0 text-primary" data-id="TextBody" style="max-width: 500px;"><div class="sc-48082a-0 bguyED" tabindex="0">Winds of Yawanawa by Yawanawa and Refik Anadol</div></span><div class="sc-85796277-0 dfIUJZ" data-testid="verification-icon"><div aria-hidden="true" class="VerificationIcon--icon"><svg aria-label="verified-icon" class="sc-9c65691d-0 hDXJCP" fill="none" viewBox="0 0 30 30"><path d="M13.474 2.80108C14.2729 1.85822 15.7271 1.85822 16.526 2.80108L17.4886 3.9373C17.9785 4.51548 18.753 4.76715 19.4892 4.58733L20.9358 4.23394C22.1363 3.94069 23.3128 4.79547 23.4049 6.0278L23.5158 7.51286C23.5723 8.26854 24.051 8.92742 24.7522 9.21463L26.1303 9.77906C27.2739 10.2474 27.7233 11.6305 27.0734 12.6816L26.2903 13.9482C25.8918 14.5928 25.8918 15.4072 26.2903 16.0518L27.0734 17.3184C27.7233 18.3695 27.2739 19.7526 26.1303 20.2209L24.7522 20.7854C24.051 21.0726 23.5723 21.7315 23.5158 22.4871L23.4049 23.9722C23.3128 25.2045 22.1363 26.0593 20.9358 25.7661L19.4892 25.4127C18.753 25.2328 17.9785 25.4845 17.4886 26.0627L16.526 27.1989C15.7271 28.1418 14.2729 28.1418 13.474 27.1989L12.5114 26.0627C12.0215 25.4845 11.247 25.2328 10.5108 25.4127L9.06418 25.7661C7.86371 26.0593 6.6872 25.2045 6.59513 23.9722L6.48419 22.4871C6.42773 21.7315 5.94903 21.0726 5.24777 20.7854L3.86969 20.2209C2.72612 19.7526 2.27673 18.3695 2.9266 17.3184L3.70973 16.0518C4.10824 15.4072 4.10824 14.5928 3.70973 13.9482L2.9266 12.6816C2.27673 11.6305 2.72612 10.2474 3.86969 9.77906L5.24777 9.21463C5.94903 8.92742 6.42773 8.26854 6.48419 7.51286L6.59513 6.0278C6.6872 4.79547 7.86371 3.94069 9.06418 4.23394L10.5108 4.58733C11.247 4.76715 12.0215 4.51548 12.5114 3.9373L13.474 2.80108Z" class="sc-9c65691d-1 Sxbrk"></path><path d="M13.5 17.625L10.875 15L10 15.875L13.5 19.375L21 11.875L20.125 11L13.5 17.625Z" fill="white" stroke="white"></path></svg></div></div></div></div></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">347 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold text-green-2" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">+90%</div></span></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">6.84 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 hhAa-dT cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">53</div></span></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">62%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">623 owners</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">4%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">43 of 1,000</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div aria-label="Add to watchlist" data-testid="rankings-watchlist-button" role="button" tabindex="0" class="sc-4d608641-1 bKkxtp"><svg class="sc-4d608641-3 flTrwJ" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.6,3.9l2.2,4.4c0.1,0.2,0.3,0.4,0.6,0.4l4.9,0.7c0.6,0.1,0.8,0.8,0.4,1.2l-3.6,3.4c-0.2,0.2-0.3,0.4-0.2,0.6  l0.8,4.9c0.1,0.6-0.5,1.1-1.1,0.8l-4.4-2.3c-0.2-0.1-0.5-0.1-0.7,0l-4.4,2.3c-0.5,0.3-1.2-0.2-1.1-0.8L7,14.8c0-0.2,0-0.5-0.2-0.6  l-3.6-3.4C2.8,10.3,3,9.5,3.6,9.4l4.9-0.7c0.2,0,0.4-0.2,0.6-0.4l2.2-4.4C11.6,3.4,12.4,3.4,12.6,3.9z" fill="none" stroke="currentColor" stroke-miterlimit="10" stroke-width="2.5"></path></svg></div></div></a></div></div><div style="top: 1056px; left: 0px; width: 1284px; writing-mode: horizontal-tb; position: absolute;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="/collection/sugartownoras" role="row"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 kOZver"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">13</div></span></div><div class="sc-c0dd234a-0 fRinzB" aria-expanded="false"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: absolute; inset: 0px;"><img alt="Collection Image" sizes="64px" srcset="https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=48 48w, https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=64 64w, https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=128 128w, https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=256 256w, https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=384 384w, https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=512 512w, https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=640 640w, https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=750 750w, https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=828 828w, https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=1080 1080w, https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=1200 1200w, https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=1920 1920w, https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=2048 2048w, https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=3840 3840w" src="https://i.seadn.io/s/raw/files/6d2c27beda3d27be82242f7321890865.gif?auto=format&amp;dpr=1&amp;w=3840" decoding="async" data-nimg="fill" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover;"></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full"><div class="sc-c0dd234a-0 sc-cac1b17-3 ckCQsp hEVFmv"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC w-full"><span class="text-md leading-md font-semibold m-0 text-primary" data-id="TextBody" style="max-width: 500px;"><div class="sc-48082a-0 bguyED" tabindex="-1">Sugartown Oras</div></span><div class="sc-85796277-0 dfIUJZ" data-testid="verification-icon"><div aria-hidden="true" class="VerificationIcon--icon"><svg aria-label="verified-icon" class="sc-9c65691d-0 hDXJCP" fill="none" viewBox="0 0 30 30"><path d="M13.474 2.80108C14.2729 1.85822 15.7271 1.85822 16.526 2.80108L17.4886 3.9373C17.9785 4.51548 18.753 4.76715 19.4892 4.58733L20.9358 4.23394C22.1363 3.94069 23.3128 4.79547 23.4049 6.0278L23.5158 7.51286C23.5723 8.26854 24.051 8.92742 24.7522 9.21463L26.1303 9.77906C27.2739 10.2474 27.7233 11.6305 27.0734 12.6816L26.2903 13.9482C25.8918 14.5928 25.8918 15.4072 26.2903 16.0518L27.0734 17.3184C27.7233 18.3695 27.2739 19.7526 26.1303 20.2209L24.7522 20.7854C24.051 21.0726 23.5723 21.7315 23.5158 22.4871L23.4049 23.9722C23.3128 25.2045 22.1363 26.0593 20.9358 25.7661L19.4892 25.4127C18.753 25.2328 17.9785 25.4845 17.4886 26.0627L16.526 27.1989C15.7271 28.1418 14.2729 28.1418 13.474 27.1989L12.5114 26.0627C12.0215 25.4845 11.247 25.2328 10.5108 25.4127L9.06418 25.7661C7.86371 26.0593 6.6872 25.2045 6.59513 23.9722L6.48419 22.4871C6.42773 21.7315 5.94903 21.0726 5.24777 20.7854L3.86969 20.2209C2.72612 19.7526 2.27673 18.3695 2.9266 17.3184L3.70973 16.0518C4.10824 15.4072 4.10824 14.5928 3.70973 13.9482L2.9266 12.6816C2.27673 11.6305 2.72612 10.2474 3.86969 9.77906L5.24777 9.21463C5.94903 8.92742 6.42773 8.26854 6.48419 7.51286L6.59513 6.0278C6.6872 4.79547 7.86371 3.94069 9.06418 4.23394L10.5108 4.58733C11.247 4.76715 12.0215 4.51548 12.5114 3.9373L13.474 2.80108Z" class="sc-9c65691d-1 Sxbrk"></path><path d="M13.5 17.625L10.875 15L10 15.875L13.5 19.375L21 11.875L20.125 11L13.5 17.625Z" fill="white" stroke="white"></path></svg></div></div></div></div></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">363 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold text-red-2" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">-35%</div></span></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC"><span class="text-md leading-md font-semibold text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">0.27 ETH</div></span></div></div><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 hhAa-dT cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">1,444</div></span></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">15%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">922 owners</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 sc-3d8bb57f-4 hsTQVh bNkKFC dsowZP gWFXML"><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">3%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">191 of 6,023</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div aria-label="Add to watchlist" data-testid="rankings-watchlist-button" role="button" tabindex="0" class="sc-4d608641-1 bKkxtp"><svg class="sc-4d608641-3 flTrwJ" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.6,3.9l2.2,4.4c0.1,0.2,0.3,0.4,0.6,0.4l4.9,0.7c0.6,0.1,0.8,0.8,0.4,1.2l-3.6,3.4c-0.2,0.2-0.3,0.4-0.2,0.6  l0.8,4.9c0.1,0.6-0.5,1.1-1.1,0.8l-4.4-2.3c-0.2-0.1-0.5-0.1-0.7,0l-4.4,2.3c-0.5,0.3-1.2-0.2-1.1-0.8L7,14.8c0-0.2,0-0.5-0.2-0.6  l-3.6-3.4C2.8,10.3,3,9.5,3.6,9.4l4.9-0.7c0.2,0,0.4-0.2,0.6-0.4l2.2-4.4C11.6,3.4,12.4,3.4,12.6,3.9z" fill="none" stroke="currentColor" stroke-miterlimit="10" stroke-width="2.5"></path></svg></div></div></a></div></div><div style="top: 792px; left: 0px; width: 1284px; writing-mode: horizontal-tb; position: absolute;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="/collection/otherside-vessels" role="row"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 kOZver"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">10</div></span></div><div class="sc-c0dd234a-0 fRinzB" aria-expanded="false"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: block; overflow: hidden; width: initial; height: initial; background: none; opacity: 1; border: 0px; margin: 0px; padding: 0px; position: absolute; inset: 0px;"><img alt="Collection Image" sizes="64px" srcset="https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=48 48w, https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=64 64w, https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=128 128w, https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=256 256w, https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=384 384w, https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=512 512w, https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=640 640w, https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=750 750w, https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=828 828w, https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=1080 1080w, https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=1200 1200w, https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=1920 1920w, https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=2048 2048w, https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=3840 3840w" src="https://i.seadn.io/gcs/files/8646d6116bb3f59822dc98f108d61f18.png?auto=format&amp;dpr=1&amp;w=3840" decoding="async" data-nimg="fill" style="position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover;"></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full"><div class="sc-c0dd234a-0 sc-cac1b17-3 ckCQsp hEVFmv"><div class="sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC w-full"><span class="text-md leading-md font-semibold m-0 text-primary" data-id="TextBody" style="max-width: 500px;"><div class="sc-48082a-0 bguyED" tabindex="-1">
div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-md leading-md font-semibold sc-3d8bb57f-0 cBJwoX text-primary" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">2%</div></span></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 igkwJV bNkKFC"><div theme="[object Object]" class="sc-c0dd234a-0 sc-24610f1f-0 sc-3d8bb57f-2 gqhhqz cMkvCR"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody">224 of 9,998</span></div></div></div><div class="sc-c0dd234a-0 sc-630fc9ab-0 lbdwUV bNkKFC"><div aria-label="Add to watchlist" data-testid="rankings-watchlist-button" role="button" tabindex="0" class="sc-4d608641-1 bKkxtp"><svg class="sc-4d608641-3 flTrwJ" viewBox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12.6,3.9l2.2,4.4c0.1,0.2,0.3,0.4,0.6,0.4l4.9,0.7c0.6,0.1,0.8,0.8,0.4,1.2l-3.6,3.4c-0.2,0.2-0.3,0.4-0.2,0.6  l0.8,4.9c0.1,0.6-0.5,1.1-1.1,0.8l-4.4-2.3c-0.2-0.1-0.5-0.1-0.7,0l-4.4,2.3c-0.5,0.3-1.2-0.2-1.1-0.8L7,14.8c0-0.2,0-0.5-0.2-0.6  l-3.6-3.4C2.8,10.3,3,9.5,3.6,9.4l4.9-0.7c0.2,0,0.4-0.2,0.6-0.4l2.2-4.4C11.6,3.4,12.4,3.4,12.6,3.9z" fill="none" stroke="currentColor" stroke-miterlimit="10" stroke-width="2.5"></path></svg></div></div></a></div></div></div>

# %%
column_data = soup.find_all('div', role = "table", tabindex="0")

# %%
print(column_data)
# Out:
# [<div role="table" style="position: relative; width: 100%; max-width: 100%; height: 8948px; max-height: 8948px;" tabindex="0"><div style="width: 1285px; position: absolute; writing-mode: horizontal-tb; top: 616px; left: 0px;"><div class="sc-c0dd234a-0 sc-32505186-0 ckCQsp jBJmUa"><a class="no-underline cursor-pointer text-interactive-primary hover:text-interactive-primary-hover disabled:pointer-events-none disabled:opacity-40 sc-c0dd234a-0 sc-630fc9ab-0 sc-a4a0e478-0 sc-c0650ae3-0 cFoNOd bNkKFC duoFdU ghlwJC" href="https://opensea.io/collection/azuki" role="row"><div class="sc-c0dd234a-0 sc-24610f1f-0 kOZver" theme="[object Object]"><div class="sc-c0dd234a-0 ezmuCZ"><span class="text-sm leading-sm font-semibold sc-3d8bb57f-1 hLjPCO" data-id="TextBody"><div class="sc-48082a-0 axQXd" tabindex="-1">8</div></span></div><div aria-expanded="false" class="sc-c0dd234a-0 fRinzB"><div class="sc-cac1b17-2 IzJeB" style="height: 64px; width: 64px;"><span style="box-sizing: border-box; display: bl
# ...

# %%
for row in column_data: 
    row_data = row.find_all('div', class_ ='sc-c0dd234a-0 ezmuCZ')
    individual_row_data1 = [data.text.strip() for data in row_data]
    print(individual_row_data1)
# Out:
# ['8', '12', '14', '15', '13', '10', '11', '9', '4', '6', '7', '5', '2', '3', '1']

# %%
for row in column_data: 
    row_data = row.find_all('div', class_ ='sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full')
    individual_row_data2 = [data.text.strip() for data in row_data]
    print(individual_row_data2)
# Out:
# ['Azuki', 'Otherdeed Expanded', 'Sugartown Oras', 'Winds of Yawanawa by Yawanawa and Refik Anadol', 'Otherside Koda', 'Otherside Vessels', 'CLONE X - X TAKASHI MURAKAMI', 'Wrapped Cryptopunks', 'DeGods', 'Milady Maker', 'Bored Ape Kennel Club', 'Pudgy Penguins', 'Mutant Ape Yacht Club', 'CryptoPunks', 'Bored Ape Yacht Club']

# %%
for row in column_data: 
    row_data = row.find_all('div', class_ ='sc-c0dd234a-0 sc-630fc9ab-0 sc-99655001-0 loioLq bNkKFC dsowZP w-full')
    individual_row_data2 = [data.text.strip() for data in row_data]
    print(individual_row_data2)
# Out:
# ['Azuki', 'Otherdeed Expanded', 'Sugartown Oras', 'Winds of Yawanawa by Yawanawa and Refik Anadol', 'Otherside Koda', 'Otherside Vessels', 'CLONE X - X TAKASHI MURAKAMI', 'Wrapped Cryptopunks', 'DeGods', 'Milady Maker', 'Bored Ape Kennel Club', 'Pudgy Penguins', 'Mutant Ape Yacht Club', 'CryptoPunks', 'Bored Ape Yacht Club']

# %%
for row in column_data: 
    row_data = row.find_all('div', class_ ='sc-c0dd234a-0 sc-630fc9ab-0 gPLTnN bNkKFC')
    individual_row_data3 = [data.text.strip() for data in row_data]
    print(individual_row_data3)
# Out:
# ['600 ETH', '4.18 ETH', '356 ETH', '0.27 ETH', '349 ETH', '0.27 ETH', '347 ETH', '6.75 ETH', '353 ETH', '3.35 ETH', '450 ETH', '0.23 ETH', '374 ETH', '1.34 ETH', '560 ETH', '52 ETH', '1,650 ETH', '3.25 ETH', '1,132 ETH', '2.05 ETH', '1,069 ETH', '1.62 ETH', '1,608 ETH', '5.75 ETH', '2,678 ETH', '5.08 ETH', '1,660 ETH', '—', '3,552 ETH', '27.20 ETH']

# %%
series1 = pd.Series(individual_row_data1)

series2 = pd.Series(individual_row_data2)

series3 = pd.Series(individual_row_data3)

series1 = series1.sort_index(ascending=False)

series2 = series2.sort_index(ascending=False)

series3 = series3.sort_index(ascending=False)

df = pd.concat([series1, series2, series3], axis=1, ignore_index = False)

df = df.dropna()

df = df.rename(columns={0: '#', 1: 'Collection', 2: 'Volume'})

df['#'] = df['#'].astype(int)

df = df.set_index('#')

df = df.sort_index()

# %%
print(df)
# Out:
#                                         Collection    Volume
# #
# 1                             Bored Ape Yacht Club   560 ETH
# 2                            Mutant Ape Yacht Club   374 ETH
# 3                                      CryptoPunks  1.34 ETH
# 4                                           DeGods   353 ETH
# 5                                   Pudgy Penguins  0.23 ETH
# 6                                     Milady Maker  3.35 ETH
# 7                            Bored Ape Kennel Club   450 ETH
# 8                                            Azuki   600 ETH
# 9                              Wrapped Cryptopunks  6.75 ETH
# 10                               Otherside Vessels  0.27 ETH
# 11                    CLONE X - X TAKASHI MURAKAMI   347 ETH
# 12                              Otherdeed Expanded  4.18 ETH
# 13                                  Otherside Koda   349 ETH
# 14                                  Sugartown Oras   356 ETH
# ...
